# %%
# Out:
#                    Exoplanet Name  Discovered Year
# 0                        51 Peg b             1995
# 1                        51 Peg b             1995
# 2                        51 Peg b             1995
# 3                        51 Peg b             1995
# 4                        51 Peg b             1995
# 5                      16 Cyg B b             1996
# 6                        47 UMa b             1996
# 7                        47 UMa b             1996
# 8                        47 UMa b             1996
# 9                        47 UMa b             1996
# 10                       47 UMa b             1996
# 11                     16 Cyg B b             1996
# 12                     16 Cyg B b             1996
# 13                     16 Cyg B b             1996
# 14                     16 Cyg B b             1996
# 15                     16 Cyg B b             1996
# 16                       55 Cnc b             1996
# ...

# %%
import pandas as pd

df = pd.read_csv('Ordered_data.csv')
pd.set_option('display.max_rows', None)
display()
